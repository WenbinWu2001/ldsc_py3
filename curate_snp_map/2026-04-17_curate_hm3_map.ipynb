# %% [markdown]
# # Curate the snp map for hm3 snps
#
# The map contains the following entires:
#
#
# - chr
# - hg19_pos
# - hg38_pos
# - rsID
# - hg19_Uniq_ID (if available. otherwise set to missing value)
# - hg38_Uniq_ID (if available. otherwise set to missing value)
# - MAF (if available. otherwise set to missing value)
# - REF (if available. otherwise set to missing value)
# - ALT (if available. otherwise set to missing value)

# %%
import pandas as pd

df = pd.read_parquet("ldsc_py3_Jerry_workspace/ldsc_py3_Jerry/.worktrees/restructure/result_consistency_checks/resources/ref_panel/R2_table/hm3_only/EUR_chr22_ann_MAF0.01_SNPonly_hm3only.parquet")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_parquet("ldsc_py3_Jerry_workspace/ldsc_py3_Jerry/.worktrees/restructure/result_consistency_checks/resources/ref_panel/R2_table/hm3_only/EUR_chr22_ann_MAF0.01_SNPonly_hm3only.parquet")
#       4 df.head()
#
# File ~/miniforge3/envs/ldsc-py3-Jerry/lib/python3.11/site-packages/pandas/io/parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# ...
