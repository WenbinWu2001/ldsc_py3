# %% [markdown]
# # Curate the snp map for hm3 snps
#
# The map contains the following entires:
#
#
# - chr
# - hg19_pos
# - hg38_pos
# - rsID
# - hg19_Uniq_ID (if available. otherwise set to missing value)
# - hg38_Uniq_ID (if available. otherwise set to missing value)
# - MAF (if available. otherwise set to missing value)
# - REF (if available. otherwise set to missing value)
# - ALT (if available. otherwise set to missing value)

# %%
import pandas as pd

df = pd.read_parquet("/Users/wenbinwu/Documents_local/Research/SullivanLab/LDSC/repos/ldsc_py3_Jerry_workspace/ldsc_py3_Jerry_workspace/ldsc_py3_Jerry/.worktrees/restructure/result_consistency_checks/resources/ref_panel/R2_table/hm3_only/EUR_chr22_LD_MAF0.01_SNPonly_hm3only.parquet")
df.head()

# df = pd.read_parquet("/Users/wenbinwu/Documents_local/Research/SullivanLab/LDSC/repos/ldsc_py3_Jerry_workspace/ldsc_py3_Jerry_workspace/ldsc_py3_Jerry/.worktrees/restructure/result_consistency_checks/resources/ref_panel/R2_table/hm3_only/EUR_chr22_ann_MAF0.01_SNPonly_hm3only.parquet")
# df.head()
# Out:
#   chr     rsID_1     rsID_2  hg38_bp1  hg38_bp2  hg19_bp_1  hg19_bp_2
# 0  22  rs7287144  rs5748662  16406147  16412132   16886873   16892858  \
# 1  22  rs7287144  rs4010558  16406147  16416036   16886873   16896762
# 2  22  rs7287144  rs5747620  16406147  16551808   16886873   17032698
# 3  22  rs5748662  rs4010558  16412132  16416036   16892858   16896762
# 4  22  rs5748662  rs5747620  16412132  16551808   16892858   17032698
#
#     hg38_Uniq_ID_1   hg38_Uniq_ID_2   hg19_Uniq_ID_1   hg19_Uniq_ID_2     R2
# 0  22:16406147:A:G  22:16412132:G:A  22:16886873:A:G  22:16892858:G:A  0.986  \
# 1  22:16406147:A:G  22:16416036:G:A  22:16886873:A:G  22:16896762:G:A  0.891
# 2  22:16406147:A:G  22:16551808:T:C  22:16886873:A:G  22:17032698:T:C  0.277
# 3  22:16412132:G:A  22:16416036:G:A  22:16892858:G:A  22:16896762:G:A  0.897
# 4  22:16412132:G:A  22:16551808:T:C  22:16892858:G:A  22:17032698:T:C  0.278
#
#    Dprime +/-corr
# 0   0.995       +
# 1   0.995       +
# 2   0.764       +
# ...
